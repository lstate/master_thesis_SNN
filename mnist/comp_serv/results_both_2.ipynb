# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math

import random
import cmath

# %%
accuracy = np.load('lin_alg_grad_descent_res/grad_descent_results_a.txt.npy')
confusion_matrix = np.load('lin_alg_grad_descent_res/grad_descent_results_c.txt.npy')
threshold = np.load('lin_alg_grad_descent_res/grad_descent_results_t.txt.npy')

# %%
accuracy_la = np.load('lin_alg_grad_descent_res/la_results_a.txt.npy')
confusion_matrix_la = np.load('lin_alg_grad_descent_res/la_results_c.txt.npy')
threshold_la = np.load('lin_alg_grad_descent_res/la_results_t.txt.npy')

# %%
accuracy_2 = np.load('lin_alg_grad_descent_res_2/grad_descent_results_a.txt.npy')
confusion_matrix_2 = np.load('lin_alg_grad_descent_res_2/grad_descent_results_c.txt.npy')
threshold_2 = np.load('lin_alg_grad_descent_res_2/grad_descent_results_t.txt.npy')

# %%
accuracy_la_2 = np.load('lin_alg_grad_descent_res_2/la_results_a.txt.npy')
confusion_matrix_la_2 = np.load('lin_alg_grad_descent_res_2/la_results_c.txt.npy')
threshold_la_2 = np.load('lin_alg_grad_descent_res_2/la_results_t.txt.npy')

# %%
accuracy_la_3 = np.load('retraining_mnist/la_results_a.txt.npy')
confusion_matrix_la_3 = np.load('retraining_mnist/la_results_c.txt.npy')
threshold_la_3 = np.load('retraining_mnist/la_results_t.txt.npy')

# %%
accuracy_3 = np.load('retraining_mnist/grad_descent_results_a.txt.npy')
confusion_matrix_3 = np.load('retraining_mnist/grad_descent_results_c.txt.npy')
threshold_3 = np.load('retraining_mnist/grad_descent_results_t.txt.npy')

# %%
feature_list = [20 *3, 60 *3, 100 * 3, 150 *3]
feature_list_2 = [20 *3, 60 *3, 100 * 3, 150 *3, 200 * 3]

# %%
plt.figure(figsize = (10, 7))
plt.rcParams.update({'font.size': 16}) #change font size for figures

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

plt.plot(feature_list, accuracy_la, 'r--', label = r'module 1, feature set 1, $\tau = 13.5$')
plt.plot(feature_list_2, accuracy_la_2, 'r-', label = r'module 1, feature set 2, $\tau = 13.5$')
plt.plot(feature_list_2, accuracy_la_3, 'r:', label = r'module 1, feature set 2, $\tau = 5$')

plt.plot(feature_list, accuracy, 'b--', label = r'module 2, feature set 1, $\tau = 13.5$')
plt.plot(feature_list_2, accuracy_2,  'b-', label = r'module 2, feature set 2, $\tau = 13.5$')
plt.plot(feature_list_2, accuracy_3,  'b:', label = r'module 2, feature set 2, $\tau = 5$')

plt.xlabel('features')
plt.ylabel('accuracy')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
#plt.savefig('mnist_accuracy.pdf', bbox_inches='tight')

plt.show()

# %%
print(accuracy)
print(accuracy_2)
print(accuracy_la)
print(accuracy_la_2)
print(feature_list_2)

print(accuracy_3)
print(accuracy_la_3)
# Out:
# [0.5637 0.7045 0.7867 0.8368]
# [0.5988 0.7445 0.7901 0.8248 0.8588]
# [0.5074 0.6512 0.7548 0.7638]
# [0.5412 0.6461 0.6605 0.7604 0.8112]
# [60, 180, 300, 450, 600]
# [0.5734 0.7008 0.7757 0.8128 0.841 ]
# [0.4887 0.571  0.5736 0.6952 0.7668]
